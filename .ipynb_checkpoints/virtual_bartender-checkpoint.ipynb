# %%
# Import Dependencies
import os
import csv

import pandas as pd
import numpy as np

import json
import requests

from scipy.stats import sem
from pprint import pprint

# %% [markdown]
# ## Raw data import

# %%
#raw data import
drink1 = "all_drinks.csv"
drink1_input = pd.read_csv(drink1, low_memory=False)
drink1_input= pd.DataFrame(drink1_input)

#drink1_input.head()
#drink1_input.columns
#drink1_input.count()

# %%
#rename columns
drink1 = drink1_input.rename(columns={'strDrink':'drink','idDrink':'drink_id','strCategory': 'Category','strDrinkThumb':'cocktail_pic',
                                      'strMeasure1':'Measure_01','strIngredient1':'Ingredient_01', 
                                      'strMeasure2':'Measure_02','strIngredient2':'Ingredient_02',
                                      'strMeasure3':'Measure_03','strIngredient3':'Ingredient_03',
                                      'strMeasure4':'Measure_04','strIngredient4':'Ingredient_04',
                                      'strMeasure5':'Measure_05','strIngredient5':'Ingredient_05',
                                      'strMeasure6':'Measure_06','strIngredient6':'Ingredient_06',
                                      'strMeasure7':'Measure_07','strIngredient7':'Ingredient_07',
                                      'strMeasure8':'Measure_08', 'strIngredient8':'Ingredient_08',
                                      'strMeasure9':'Measure_09','strIngredient9':'Ingredient_09',
                                      'strMeasure10':'Measure_10','strIngredient10':'Ingredient_10',
                                      'strMeasure11':'Measure_11','strIngredient11':'Ingredient_11',
                                      'strMeasure12':'Measure_12','strIngredient12':'Ingredient_12',
                                      'strMeasure13':'Measure_13','strIngredient13':'Ingredient_13',
                                      'strMeasure14':'Measure_14','strIngredient14':'Ingredient_14',
                                      'strMeasure15':'Measure_15','strIngredient15':'Ingredient_15',
                                      'strInstructions':'Instructions'})

#drop columns
drink1 = drink1[['drink', 'drink_id', 'Category', 'cocktail_pic', 'Ingredient_01',
       'Ingredient_10', 'Ingredient_11', 'Ingredient_12','Ingredient_02', 'Ingredient_03',
       'Ingredient_04', 'Ingredient_05', 'Ingredient_06', 'Ingredient_07',
       'Ingredient_08', 'Ingredient_09', 'Instructions', 'Measure_01',
       'Measure_10', 'Measure_11', 'Measure_12', 'Measure_02', 'Measure_03', 'Measure_04', 'Measure_05',
       'Measure_06', 'Measure_07', 'Measure_08', 'Measure_09']]

# drink1.columns
# drink1.count()
# drink1.dtypes

# %%
#concatenate ingredients with measurement 
drink1["Ingred1"] = drink1['Measure_01'] +" " + drink1['Ingredient_01'] 
drink1["Ingred2"] = drink1['Measure_02'] +" " + drink1['Ingredient_02']
drink1["Ingred3"] = drink1['Measure_03'] +" " + drink1['Ingredient_03']
drink1["Ingred4"] = drink1['Measure_04'] +" " + drink1['Ingredient_04']
drink1["Ingred5"] = drink1['Measure_05'] +" " + drink1['Ingredient_05']
drink1["Ingred6"] = drink1['Measure_06'] +" " + drink1['Ingredient_06'] 
drink1["Ingred7"] =drink1['Measure_07'] +" " + drink1['Ingredient_07']
drink1["Ingred8"] = drink1['Measure_08'] +" " + drink1['Ingredient_08']
drink1["Ingred9"] = drink1['Measure_09'] +" " + drink1['Ingredient_09'] 
drink1["Ingred10"] = drink1['Measure_10'] +" " + drink1['Ingredient_10'] 
drink1["Ingred11"] = drink1['Measure_11'] +" " + drink1['Ingredient_11']
drink1["Ingred12"] = drink1['Measure_12'] +" " + drink1['Ingredient_12'] 


# drink1.columns

# %%
# drop columns
drink_data = drink1[['drink', 'drink_id', 'Category', 'cocktail_pic', 
       'Ingred1', 'Ingred2', 'Ingred3', 'Ingred4', 'Ingred5', 'Ingred6',
       'Ingred7', 'Ingred8', 'Ingred9', 'Ingred10', 'Ingred11', 'Ingred12', 'Instructions']]

# drink_data.head()
# drink_data.dtypes
# export to csv to work in excel
# drink_data.to_csv("drinks_edited.csv", index=False, header=True)

# %% [markdown]
# ## New file to work with

# %%
drink_rev = "drinks.csv"
drink_rev1 = pd.read_csv(drink_rev, low_memory=False)
drink_rev1= pd.DataFrame(drink_rev1)

drink_rev1.head()
# Out:
#                                   drink  drink_id              Category  \
# 0  '57 Chevy with a White License Plate     14029              Cocktail
# 1                        1-900-FUK-MEUP     15395                  Shot
# 2                      110 in the shade     15423                  Beer
# 3                151 Florida Bushwacker     14588  Milk / Float / Shake
# 4                           155 Belmont     15346              Cocktail
#
#                                         cocktail_pic  \
# 0  http://www.thecocktaildb.com/images/media/drin...
# 1  http://www.thecocktaildb.com/images/media/drin...
# 2  http://www.thecocktaildb.com/images/media/drin...
# 3  http://www.thecocktaildb.com/images/media/drin...
# 4  http://www.thecocktaildb.com/images/media/drin...
#
#                       Ingred1                Ingred2  \
# 0  1 oz white  Creme de Cacao            1 oz  Vodka
# 1      1/2 oz  Absolut Kurant  1/4 oz  Grand Marnier
# ...

# %%
#change drinks into a list for random generator
drink_list = drink_rev1["drink"]
drink_list.head()
# Out:
# 0    '57 Chevy with a White License Plate
# 1                          1-900-FUK-MEUP
# 2                        110 in the shade
# 3                  151 Florida Bushwacker
# 4                             155 Belmont
# Name: drink, dtype: object

# %%
#create random generator for "suprise me button"

import random

number_of_samples = 1
random_drink = random.choices(population=drink_list, k=number_of_samples)[0]

print(random_drink)
drink_rev1[drink_rev1['drink'] == random_drink]
# Out:
# Monkey Gland
#             drink  drink_id        Category  \
# 378  Monkey Gland     17189  Ordinary Drink
#
#                                           cocktail_pic    Ingred1  \
# 378  http://www.thecocktaildb.com/images/media/drin...  2 oz  Gin
#
#                 Ingred2               Ingred3           Ingred4 Ingred5  \
# 378  1 tsp  Benedictine  1/2 oz  Orange juice  1 tsp  Grenadine     NaN
#
#     Ingred6 Ingred7 Ingred8 Ingred9 Ingred10 Ingred11 Ingred12  \
# 378     NaN     NaN     NaN     NaN      NaN      NaN      NaN
#
#                                            Ingredients  \
# 378  2 oz  Gin,  1 tsp  Benedictine, 1/2 oz  Orange...
#
#                                           Instructions
# 378  Shake well over ice cubes in a shaker, strain ...

# %%
drink_recipe = drink_rev1[["drink", "Ingredients"]]
drink_recipe.head()
# Out:
#                                   drink  \
# 0  '57 Chevy with a White License Plate
# 1                        1-900-FUK-MEUP
# 2                      110 in the shade
# 3                151 Florida Bushwacker
# 4                           155 Belmont
#
#                                          Ingredients
# 0           1 oz white  Creme de Cacao,  1 oz  Vodka
# 1  1/2 oz  Absolut Kurant,  1/4 oz  Grand Marnier...
# 2                     16 oz  Lager,  1.5 oz  Tequila
# 3  1/2 oz  Malibu rum,  1/2 oz  Light rum, 1/2 oz...
# 4  1 shot  Dark rum,  2 shots  Light rum, 1 shot ...

# %% [markdown]
# ## Create Recommender

# %% [markdown]
# #recommender based on user input
# #compute correlation between drink (a) ingredients and the similiarity of other drinks in the dataset
#
# #create drink_matrix
# drink_matrix = drink1_input(index="", columns="", values= "")
#
# user_rating = drink_matrix['Air Force One (1997)']
# contact_user_rating = drink_matrix['Contact (1997)']
#
# #sample code
# movie_matrix = df.pivot_table(index='user_id', columns='title', values='rating')
# movie_matrix.head()AFO_user_rating = movie_matrix['Air Force One (1997)']
# contact_user_rating = movie_matrix['Contact (1997)']
# ratings.sort_values('number_of_ratings', ascending=False).head(10)
#
# #compute the correlation between two dataframes we use pandas corwith functionality.
# #Corrwith computes the pairwise correlation of rows or columns of two dataframe objects.
# similar_to_air_force_one=movie_matrix.corrwith(AFO_user_rating)

# %%
#create drink_matrix; import new dependencies

# %pyspark
import pyspark
from pyspark.ml.feature import Tokenizer, StopWordsRemover
from pyspark.sql.functions import col, udf
from pyspark.sql.types import IntegerType
from pyspark.sql import SparkSession

# %%
# convert to spark df
drink_spk = spark.createDataFrame(drink_rev1)
drink_spk.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3f3c3f7afec1> in <module>
# ----> 1 drink_spk = spark.createDataFrame(drink_rev1)
#       2 drink_spk.show()
#
# NameError: name 'spark' is not defined

# %%
# Instantiate Remover
remover = StopWordsRemover(inputCol="raw", outputCol="filtered")

# Transform and show data
remover.transform(drink_spk).show(truncate=False)

# Tokenize the words
tokenizer = Tokenizer(inputCol="recipe", outputCol="ingredients")
drink_Data = tokenizer.transform(drink_spk)
drink_Data.show()

# %%
# %pyspark
# Run the hashing term frequency
hashing = HashingTF(inputCol="ingredients", outputCol="hashedValues", numFeatures=pow(2,4))

# Transform into a DF
hashed_drinks = hashing.transform(wordsData)

# Display new DataFrame
hashed_drinks.show(truncate=False)

# %%
# %pyspark
# Fit the IDF on the data set 
idf = IDF(inputCol="hashedValues", outputCol="features")
idfModel = idf.fit(hashed_drinks)
rescaled_drinkData = idfModel.transform(hashed_drinks)
rescaled_drinkData.select("words", "features").show(truncate=False)

# %% [markdown]
# Code for mongo db when/ if needed

# %%
#output recipe for random drink

#chnge df to mongodb?

from pymongo import MongoClient
client = MongoClient('mongodb://localhost:27017/')
db = client.test
collection = db.collection
drink_recipe = collection.insert_many(drink1_input.to_dict('records'))

pprint(list(collection.find()))

# %%
#drink2 = "hotaling_cocktails.csv"
#drink2_input = pd.read_csv(drink2, low_memory=False)
#drink2_input
